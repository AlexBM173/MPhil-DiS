# %% [markdown]
# # Fashion MNIST
#
# ## Neural network tests

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import fashion_mnist #to import our dataset
from tensorflow.keras.models import Sequential, Model # imports our type of network
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input, BatchNormalization # imports our layers we want to use

from tensorflow.python.keras.losses import categorical_crossentropy #loss function
from tensorflow.keras.optimizers import Adam, SGD #optimisers
from tensorflow.keras.utils import to_categorical #some function for data preparation

from tensorflow.keras.callbacks import ModelCheckpoint #checkpoints used to keep track of best model

from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('float32')
# Out:
# 2025-11-16 21:46:03.658835: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-16 21:46:05.066495: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-16 21:46:08.462943: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
batch_size = 128
num_classes = 10
epochs = 20

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()


x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalise the data
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples

# %%
input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu')(x)
x = Dense(200, activation='relu')(x)
y = Dense(num_classes, activation='softmax')(x)

model= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763329576.447004  307503 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3537 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,210 (778.16 KB)
#  Trainable params: 199,210 (778.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history1=model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 2025-11-16 21:46:21.143229: I external/local_xla/xla/service/service.cc:163] XLA service 0x7aa2ec017c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-16 21:46:21.143277: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2025-11-16 21:46:21.196017: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-16 21:46:21.404559: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2025-11-16 21:46:22.401982: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_430', 12 bytes spill stores, 12 bytes spill loads
#  35/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5026 - loss: 1.4842
# I0000 00:00:1763329581.266708  307866 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 456/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7583 - loss: 0.7013
# 2025-11-16 21:46:23.768422: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:46:24.475577: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_181', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-16 21:46:25.114051: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_430', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-11-16 21:46:25.210339: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_432', 8 bytes spill stores, 8 bytes spill loads
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8189 - loss: 0.5153 - val_accuracy: 0.8424 - val_loss: 0.4319
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8674 - loss: 0.3650 - val_accuracy: 0.8637 - val_loss: 0.3794
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8801 - loss: 0.3264 - val_accuracy: 0.8776 - val_loss: 0.3470
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8881 - loss: 0.3015 - val_accuracy: 0.8734 - val_loss: 0.3483
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8952 - loss: 0.2847 - val_accuracy: 0.8675 - val_loss: 0.3608
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8992 - loss: 0.2694 - val_accuracy: 0.8809 - val_loss: 0.3242
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9025 - loss: 0.2603 - val_accuracy: 0.8838 - val_loss: 0.3250
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9075 - loss: 0.2459 - val_accuracy: 0.8816 - val_loss: 0.3241
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9109 - loss: 0.2373 - val_accuracy: 0.8852 - val_loss: 0.3168
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9146 - loss: 0.2256 - val_accuracy: 0.8824 - val_loss: 0.3310
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9167 - loss: 0.2184 - val_accuracy: 0.8825 - val_loss: 0.3353
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9202 - loss: 0.2104 - val_accuracy: 0.8922 - val_loss: 0.3189
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9234 - loss: 0.2012 - val_accuracy: 0.8888 - val_loss: 0.3287
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9274 - loss: 0.1939 - val_accuracy: 0.8866 - val_loss: 0.3370
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ -0s -1118us/step - accuracy: 0.9283 - loss: 0.1882 - val_accuracy: 0.8913 - val_loss: 0.3223
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9317 - loss: 0.1798 - val_accuracy: 0.8880 - val_loss: 0.3475
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9345 - loss: 0.1746 - val_accuracy: 0.8893 - val_loss: 0.3407
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9363 - loss: 0.1676 - val_accuracy: 0.8958 - val_loss: 0.3316
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9395 - loss: 0.1590 - val_accuracy: 0.8901 - val_loss: 0.3523
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9398 - loss: 0.1553 - val_accuracy: 0.8859 - val_loss: 0.3687

# %%
# Let's add some regularisation:

from tensorflow.keras.regularizers import l1, l2

#dropout_rate = 0.2

input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu',activity_regularizer=l1(0.1))(x)
x = Dense(200, activation='relu',activity_regularizer=l1(0.2))(x)
y = Dense(num_classes, activation='softmax')(x)

model= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,210 (778.16 KB)
#  Trainable params: 199,210 (778.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Dropout

dropout_rate = 0.2

input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu',activity_regularizer=l1(0.1))(x)
x = Dropout(rate=dropout_rate)(x)
x = Dense(200, activation='relu',activity_regularizer=l1(0.2))(x)
x = Dropout(rate=dropout_rate)(x)
y = Dense(num_classes, activation='softmax')(x)

model_dropout= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model_dropout.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
model_dropout.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,210 (778.16 KB)
#  Trainable params: 199,210 (778.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history4=model_dropout.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 459/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1029 - loss: 46.6549
# 2025-11-16 21:47:06.510369: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:47:07.148635: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1232', 4 bytes spill stores, 4 bytes spill loads
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.0997 - loss: 9.8940 - val_accuracy: 0.1000 - val_loss: 2.3110
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0984 - loss: 2.3074 - val_accuracy: 0.1000 - val_loss: 2.3089
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0982 - loss: 2.3048 - val_accuracy: 0.1000 - val_loss: 2.3080
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0981 - loss: 2.3038 - val_accuracy: 0.1000 - val_loss: 2.3074
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0989 - loss: 2.3033 - val_accuracy: 0.1000 - val_loss: 2.3070
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0988 - loss: 2.3030 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0981 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0989 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ -1s -1155us/step - accuracy: 0.0998 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0986 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0972 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0983 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0963 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0989 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0976 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0981 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0971 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0974 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0984 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1000 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3069

# %%
# Batch-Normalisation

dropout_rate = 0.2

input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(200, activation='relu')(x)
x = Dropout(rate=dropout_rate)(x)
y = Dense(num_classes, activation='softmax')(x)

model_batch_normalisation= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model_batch_normalisation.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
model_batch_normalisation.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200)            │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 200,010 (781.29 KB)
#  Trainable params: 199,610 (779.73 KB)
#  Non-trainable params: 400 (1.56 KB)

# %%
history4=model_batch_normalisation.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8317 - loss: 0.4663 - val_accuracy: 0.8432 - val_loss: 0.4389
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8678 - loss: 0.3625 - val_accuracy: 0.8288 - val_loss: 0.4751
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8773 - loss: 0.3314 - val_accuracy: 0.8623 - val_loss: 0.3741
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ -1s -1147us/step - accuracy: 0.8868 - loss: 0.3111 - val_accuracy: 0.8650 - val_loss: 0.3736
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8918 - loss: 0.2945 - val_accuracy: 0.8395 - val_loss: 0.4434
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8969 - loss: 0.2789 - val_accuracy: 0.8747 - val_loss: 0.3567
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9008 - loss: 0.2668 - val_accuracy: 0.8660 - val_loss: 0.3651
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9050 - loss: 0.2548 - val_accuracy: 0.8671 - val_loss: 0.3612
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9059 - loss: 0.2494 - val_accuracy: 0.8679 - val_loss: 0.3645
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9100 - loss: 0.2387 - val_accuracy: 0.8811 - val_loss: 0.3324
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9123 - loss: 0.2356 - val_accuracy: 0.8698 - val_loss: 0.3821
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9140 - loss: 0.2291 - val_accuracy: 0.8834 - val_loss: 0.3349
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9169 - loss: 0.2191 - val_accuracy: 0.8780 - val_loss: 0.3572
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9197 - loss: 0.2123 - val_accuracy: 0.8736 - val_loss: 0.3851
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9216 - loss: 0.2069 - val_accuracy: 0.8826 - val_loss: 0.3557
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9242 - loss: 0.2014 - val_accuracy: 0.8707 - val_loss: 0.4001
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9257 - loss: 0.1983 - val_accuracy: 0.8747 - val_loss: 0.3665
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9260 - loss: 0.1950 - val_accuracy: 0.8794 - val_loss: 0.3594
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9291 - loss: 0.1862 - val_accuracy: 0.8832 - val_loss: 0.3447
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9309 - loss: 0.1813 - val_accuracy: 0.8861 - val_loss: 0.3701

# %%
# Saving a model

# Save the model
model_batch_normalisation.save('mnist_model_batch_normalisation.keras')


# Load the model
loaded_model = tf.keras.models.load_model('mnist_model_batch_normalisation.keras')
print("Model loaded from 'mnist_model_batch_normalisation.keras")

# Evaluate the loaded model
loss, accuracy = loaded_model.evaluate(x_test, y_test)
# Out:
# Model loaded from 'mnist_model_batch_normalisation.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8861 - loss: 0.3701

# %%
# keeping the best model on the test/validation data.

# Define a ModelCheckpoint callback
checkpoint = ModelCheckpoint('best_model.keras', 
                             monitor='val_accuracy',  # You can monitor 'val_loss' or any other metric
                             save_best_only=True, 
                             mode='max',  # Use 'max' if monitoring accuracy; 'min' if monitoring loss
                             verbose=1)

history4=model_batch_normalisation.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=[checkpoint],
          validation_data=(x_test, y_test))

best_model = tf.keras.models.load_model('best_model.keras')
# Out:
# Epoch 1/20
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9345 - loss: 0.1720
# Epoch 1: val_accuracy improved from None to 0.88200, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9321 - loss: 0.1792 - val_accuracy: 0.8820 - val_loss: 0.3685
# Epoch 2/20
# 459/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9360 - loss: 0.1694
# Epoch 2: val_accuracy improved from 0.88200 to 0.88300, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9334 - loss: 0.1745 - val_accuracy: 0.8830 - val_loss: 0.3669
# Epoch 3/20
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9346 - loss: 0.1685
# Epoch 3: val_accuracy improved from 0.88300 to 0.88510, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9344 - loss: 0.1705 - val_accuracy: 0.8851 - val_loss: 0.3644
# Epoch 4/20
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9367 - loss: 0.1625
# Epoch 4: val_accuracy improved from 0.88510 to 0.88880, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9364 - loss: 0.1644 - val_accuracy: 0.8888 - val_loss: 0.4107
# Epoch 5/20
# 457/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9394 - loss: 0.1574
# Epoch 5: val_accuracy did not improve from 0.88880
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9376 - loss: 0.1638 - val_accuracy: 0.8855 - val_loss: 0.4009
# Epoch 6/20
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1580
# Epoch 6: val_accuracy improved from 0.88880 to 0.89080, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9394 - loss: 0.1575 - val_accuracy: 0.8908 - val_loss: 0.3671
# Epoch 7/20
# 455/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9414 - loss: 0.1513
# Epoch 7: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9401 - loss: 0.1547 - val_accuracy: 0.8771 - val_loss: 0.4053
# Epoch 8/20
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9441 - loss: 0.1473
# Epoch 8: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9428 - loss: 0.1496 - val_accuracy: 0.8870 - val_loss: 0.3814
# Epoch 9/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9455 - loss: 0.1449
# Epoch 9: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9422 - loss: 0.1496 - val_accuracy: 0.8865 - val_loss: 0.3812
# Epoch 10/20
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9445 - loss: 0.1409
# Epoch 10: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9426 - loss: 0.1468 - val_accuracy: 0.8906 - val_loss: 0.4021
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9481 - loss: 0.1369
# Epoch 11: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9442 - loss: 0.1444 - val_accuracy: 0.8806 - val_loss: 0.4215
# Epoch 12/20
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9472 - loss: 0.1354
# Epoch 12: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9459 - loss: 0.1389 - val_accuracy: 0.8474 - val_loss: 0.6474
# Epoch 13/20
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9482 - loss: 0.1359
# Epoch 13: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9463 - loss: 0.1397 - val_accuracy: 0.8856 - val_loss: 0.4066
# Epoch 14/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9474 - loss: 0.1332
# Epoch 14: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9464 - loss: 0.1378 - val_accuracy: 0.8876 - val_loss: 0.4003
# Epoch 15/20
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9496 - loss: 0.1306
# Epoch 15: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1331 - val_accuracy: 0.8863 - val_loss: 0.4522
# Epoch 16/20
#  14/469 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9441 - loss: 0.1489
# Epoch 16: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ -0s -981us/step - accuracy: 0.9491 - loss: 0.1289 - val_accuracy: 0.8846 - val_loss: 0.4572
# Epoch 17/20
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9528 - loss: 0.1217
# Epoch 17: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9507 - loss: 0.1259 - val_accuracy: 0.8856 - val_loss: 0.4611
# Epoch 18/20
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9537 - loss: 0.1197
# Epoch 18: val_accuracy did not improve from 0.89080
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9520 - loss: 0.1255 - val_accuracy: 0.8886 - val_loss: 0.4586
# Epoch 19/20
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9556 - loss: 0.1160
# Epoch 19: val_accuracy improved from 0.89080 to 0.89100, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9537 - loss: 0.1216 - val_accuracy: 0.8910 - val_loss: 0.4364
# Epoch 20/20
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9559 - loss: 0.1165
# Epoch 20: val_accuracy did not improve from 0.89100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9535 - loss: 0.1220 - val_accuracy: 0.8767 - val_loss: 0.4631

# %%
import optuna

# Optuna objective function
def objective(trial):
    # Suggest hyperparameters
    num_layers = trial.suggest_int('num_layers', 1, 3)
    activation = trial.suggest_categorical('activation', ['relu', 'sigmoid', 'gelu', 'leaky_relu', 'celu', 'elu'])
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.5)
    units = trial.suggest_int('units', 32, 128)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    
    # Build the model
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    
    for _ in range(num_layers):
        model.add(Dense(units=units, activation=activation))
        model.add(Dropout(rate=dropout_rate))
    
    model.add(Dense(10, activation='softmax'))
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    # Train the model
    history = model.fit(x_train, y_train, 
                        validation_split=0.2,
                        epochs=5,  # To keep it quick for demonstration; you can increase it
                        batch_size=128, 
                        verbose=0)
    
    # Evaluate the model
    score = model.evaluate(x_test, y_test, verbose=0)
    accuracy = score[1]
    return accuracy

# Create an Optuna study and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)  # Set the number of trials

# Print the best trial
print('Best trial:')
print(f' Value: {study.best_trial.value}')
print(' Params: ')
for key, value in study.best_trial.params.items():
    print(f'    {key}: {value}')
# Out:
# [I 2025-11-16 21:55:54,740] A new study created in memory with name: no-name-10e9f980-dc65-49b1-b617-244b8d207768
# /home/alex/projects/m1_work/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2025-11-16 21:56:11,154] Trial 0 finished with value: 0.8356000185012817 and parameters: {'num_layers': 1, 'activation': 'celu', 'dropout_rate': 0.17349742324100098, 'units': 72, 'learning_rate': 0.0002188736600474409}. Best is trial 0 with value: 0.8356000185012817.
# [I 2025-11-16 21:56:21,832] Trial 1 finished with value: 0.7390999794006348 and parameters: {'num_layers': 1, 'activation': 'celu', 'dropout_rate': 0.42443254955452686, 'units': 65, 'learning_rate': 2.2051029991267583e-05}. Best is trial 0 with value: 0.8356000185012817.
# 2025-11-16 21:56:27.998627: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:28.347532: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_357', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:56:28.618371: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_165', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2025-11-16 21:56:40,042] Trial 2 finished with value: 0.8468000292778015 and parameters: {'num_layers': 3, 'activation': 'gelu', 'dropout_rate': 0.3846035459125534, 'units': 66, 'learning_rate': 0.0005493110516449215}. Best is trial 2 with value: 0.8468000292778015.
# 2025-11-16 21:56:41.532310: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:41.532413: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:41.532451: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:42.953411: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_954', 272 bytes spill stores, 268 bytes spill loads
#
# 2025-11-16 21:56:43.111005: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_500', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-16 21:56:43.470087: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_992', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:56:43.680944: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_954', 220 bytes spill stores, 220 bytes spill loads
#
# 2025-11-16 21:56:44.107238: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_500', 68 bytes spill stores, 68 bytes spill loads
#
# 2025-11-16 21:56:44.161028: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_954', 376 bytes spill stores, 284 bytes spill loads
#
# 2025-11-16 21:56:44.611964: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_992', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:56:44.634683: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_992', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-16 21:56:48.391105: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:49.242225: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_76', 48 bytes spill stores, 48 bytes spill loads
#
# [I 2025-11-16 21:56:58,140] Trial 3 finished with value: 0.7548999786376953 and parameters: {'num_layers': 2, 'activation': 'elu', 'dropout_rate': 0.33238519760627505, 'units': 41, 'learning_rate': 3.567149422984392e-05}. Best is trial 2 with value: 0.8468000292778015.
# 2025-11-16 21:56:59.995550: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:59.995655: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:56:59.995694: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:00.775573: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_522', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:57:01.103357: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1062', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:57:01.150388: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_522', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-11-16 21:57:01.501798: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1005', 272 bytes spill stores, 268 bytes spill loads
#
# 2025-11-16 21:57:02.309593: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1062', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:57:02.336722: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1005', 528 bytes spill stores, 396 bytes spill loads
#
# 2025-11-16 21:57:02.477423: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1062', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-16 21:57:06.191225: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:07.085673: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_85', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-16 21:57:13.816719: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:14.775734: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_85', 648 bytes spill stores, 656 bytes spill loads
#
# 2025-11-16 21:57:14.890133: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_85', 264 bytes spill stores, 264 bytes spill loads
#
# [I 2025-11-16 21:57:17,341] Trial 4 finished with value: 0.8593000173568726 and parameters: {'num_layers': 2, 'activation': 'celu', 'dropout_rate': 0.21015714072186437, 'units': 81, 'learning_rate': 0.0032490634102591235}. Best is trial 4 with value: 0.8593000173568726.
# [I 2025-11-16 21:57:28,947] Trial 5 finished with value: 0.8320000171661377 and parameters: {'num_layers': 1, 'activation': 'celu', 'dropout_rate': 0.022828384255404288, 'units': 109, 'learning_rate': 0.00012031821815338535}. Best is trial 4 with value: 0.8593000173568726.
# [I 2025-11-16 21:57:42,354] Trial 6 finished with value: 0.7231000065803528 and parameters: {'num_layers': 1, 'activation': 'gelu', 'dropout_rate': 0.48379453640152414, 'units': 35, 'learning_rate': 3.029342973391855e-05}. Best is trial 4 with value: 0.8593000173568726.
# 2025-11-16 21:57:43.439747: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:43.439811: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:43.439821: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:44.445955: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_502', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-11-16 21:57:44.643047: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_994', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:57:44.648209: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_957', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-11-16 21:57:44.768642: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_994', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-11-16 21:57:44.795736: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_994', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:57:47.598047: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:57:48.203377: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_78', 84 bytes spill stores, 84 bytes spill loads
#
# [I 2025-11-16 21:57:54,830] Trial 7 finished with value: 0.7078999876976013 and parameters: {'num_layers': 2, 'activation': 'leaky_relu', 'dropout_rate': 0.30117636649013685, 'units': 52, 'learning_rate': 2.233085858574513e-05}. Best is trial 4 with value: 0.8593000173568726.
# [I 2025-11-16 21:58:07,927] Trial 8 finished with value: 0.7634000182151794 and parameters: {'num_layers': 1, 'activation': 'celu', 'dropout_rate': 0.3975882130785668, 'units': 63, 'learning_rate': 3.17033364440417e-05}. Best is trial 4 with value: 0.8593000173568726.
# 2025-11-16 21:58:10.909164: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:10.909267: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:10.909305: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:11.630684: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1137', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:58:12.144957: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1184', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:58:12.327717: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1184', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-11-16 21:58:12.407964: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1184', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:58:16.091324: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:22.097331: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# [I 2025-11-16 21:58:23,953] Trial 9 finished with value: 0.8413000106811523 and parameters: {'num_layers': 2, 'activation': 'gelu', 'dropout_rate': 0.43350597107383515, 'units': 100, 'learning_rate': 0.004769552806095841}. Best is trial 4 with value: 0.8593000173568726.
# 2025-11-16 21:58:28.326976: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:29.102407: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-11-16 21:58:30.266268: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:31.135660: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-16 21:58:31.297641: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-16 21:58:31.440600: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-16 21:58:37.007362: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:37.900457: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-11-16 21:58:37.997625: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 300 bytes spill stores, 300 bytes spill loads
#
# [I 2025-11-16 21:58:40,141] Trial 10 finished with value: 0.8626000285148621 and parameters: {'num_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.17821322979905066, 'units': 127, 'learning_rate': 0.0070303560293937545}. Best is trial 10 with value: 0.8626000285148621.
# 2025-11-16 21:58:44.949393: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:45.879858: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-11-16 21:58:47.027249: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:47.977557: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 96 bytes spill stores, 96 bytes spill loads
#
# 2025-11-16 21:58:48.107887: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-16 21:58:48.245032: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-16 21:58:53.547075: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:58:54.417063: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 660 bytes spill stores, 656 bytes spill loads
#
# 2025-11-16 21:58:54.484708: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 300 bytes spill stores, 300 bytes spill loads
#
# [I 2025-11-16 21:58:56,651] Trial 11 finished with value: 0.8628000020980835 and parameters: {'num_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.1765629664207083, 'units': 125, 'learning_rate': 0.00983783578213724}. Best is trial 11 with value: 0.8628000020980835.
# [I 2025-11-16 21:59:11,430] Trial 12 finished with value: 0.8434000015258789 and parameters: {'num_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.12028793086240303, 'units': 127, 'learning_rate': 0.00941539998876972}. Best is trial 11 with value: 0.8628000020980835.
# [I 2025-11-16 21:59:25,219] Trial 13 finished with value: 0.8529000282287598 and parameters: {'num_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.08105727018830886, 'units': 125, 'learning_rate': 0.0011524616125279858}. Best is trial 11 with value: 0.8628000020980835.
# 2025-11-16 21:59:25.869913: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:25.869983: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:25.869998: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:26.314505: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1307', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:59:26.913263: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1361', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:59:26.953713: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1361', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:59:27.090972: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1361', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-11-16 21:59:30.005697: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:30.858499: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 68 bytes spill stores, 68 bytes spill loads
#
# 2025-11-16 21:59:31.887977: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:32.442400: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-11-16 21:59:32.559242: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 21:59:32.784884: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 44 bytes spill stores, 44 bytes spill loads
#
# 2025-11-16 21:59:38.194685: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:38.817397: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 52 bytes spill stores, 52 bytes spill loads
#
# [I 2025-11-16 21:59:40,901] Trial 14 finished with value: 0.8546000123023987 and parameters: {'num_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.25916623262993693, 'units': 108, 'learning_rate': 0.0019982624016738576}. Best is trial 11 with value: 0.8628000020980835.
# 2025-11-16 21:59:42.487785: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:42.487984: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:42.488710: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:43.472462: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_533', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-11-16 21:59:43.719518: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1364', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:59:44.277716: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1364', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 21:59:44.380499: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1312', 528 bytes spill stores, 396 bytes spill loads
#
# 2025-11-16 21:59:44.382550: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1312', 272 bytes spill stores, 268 bytes spill loads
#
# 2025-11-16 21:59:44.525865: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1364', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-16 21:59:47.587069: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:48.443483: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_76', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-11-16 21:59:49.344458: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:50.284656: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_76', 96 bytes spill stores, 96 bytes spill loads
#
# 2025-11-16 21:59:56.095823: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 21:59:57.029288: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_76', 284 bytes spill stores, 284 bytes spill loads
#
# 2025-11-16 21:59:57.093102: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_76', 296 bytes spill stores, 296 bytes spill loads
#
# [I 2025-11-16 21:59:58,589] Trial 15 finished with value: 0.845300018787384 and parameters: {'num_layers': 3, 'activation': 'relu', 'dropout_rate': 0.15237413073380335, 'units': 91, 'learning_rate': 0.009774000548912571}. Best is trial 11 with value: 0.8628000020980835.
# 2025-11-16 22:00:03.458610: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:04.364955: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 124 bytes spill stores, 124 bytes spill loads
#
# 2025-11-16 22:00:05.200222: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:05.743245: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-16 22:00:05.855349: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-16 22:00:06.117191: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-16 22:00:12.351840: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:12.984735: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_74', 16 bytes spill stores, 16 bytes spill loads
#
# [I 2025-11-16 22:00:15,324] Trial 16 finished with value: 0.8468999862670898 and parameters: {'num_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.22543290610231437, 'units': 116, 'learning_rate': 0.0009725698983096041}. Best is trial 11 with value: 0.8628000020980835.
# 2025-11-16 22:00:16.541149: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:16.541228: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:16.541268: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:17.685113: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_496', 56 bytes spill stores, 56 bytes spill loads
#
# 2025-11-16 22:00:17.691506: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_978', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 22:00:18.083474: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 272 bytes spill stores, 268 bytes spill loads
#
# 2025-11-16 22:00:18.346041: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 528 bytes spill stores, 396 bytes spill loads
#
# 2025-11-16 22:00:19.097953: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_978', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-16 22:00:19.102845: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_978', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-16 22:00:21.879230: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:22.684062: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-11-16 22:00:23.743489: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:24.623742: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-16 22:00:24.729715: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-16 22:00:24.917738: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-16 22:00:29.845882: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:30.670452: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 660 bytes spill stores, 656 bytes spill loads
#
# 2025-11-16 22:00:30.745023: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 300 bytes spill stores, 300 bytes spill loads
#
# [I 2025-11-16 22:00:32,516] Trial 17 finished with value: 0.8668000102043152 and parameters: {'num_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.06451595102477115, 'units': 93, 'learning_rate': 0.0037838086755506133}. Best is trial 17 with value: 0.8668000102043152.
# 2025-11-16 22:00:33.689222: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:33.689304: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:33.689337: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:35.533211: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_992', 120 bytes spill stores, 120 bytes spill loads
#
# 2025-11-16 22:00:38.720586: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:46.158884: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:46.790931: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_76', 68 bytes spill stores, 68 bytes spill loads
#
# [I 2025-11-16 22:00:48,943] Trial 18 finished with value: 0.8607000112533569 and parameters: {'num_layers': 2, 'activation': 'elu', 'dropout_rate': 0.005589229742338664, 'units': 90, 'learning_rate': 0.002681317666091447}. Best is trial 17 with value: 0.8668000102043152.
# 2025-11-16 22:00:53.987087: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:00:54.681939: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_78', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-16 22:00:54.803748: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_78', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-16 22:01:00.172655: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-16 22:01:00.856905: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_78', 616 bytes spill stores, 604 bytes spill loads
#
# 2025-11-16 22:01:01.068837: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_78', 260 bytes spill stores, 260 bytes spill loads
#
# [I 2025-11-16 22:01:03,010] Trial 19 finished with value: 0.8551999926567078 and parameters: {'num_layers': 2, 'activation': 'leaky_relu', 'dropout_rate': 0.06886757056417186, 'units': 93, 'learning_rate': 0.0011567036428706992}. Best is trial 17 with value: 0.8668000102043152.
# Best trial:
#  Value: 0.8668000102043152
#  Params:
#     num_layers: 2
#     activation: sigmoid
#     dropout_rate: 0.06451595102477115
#     units: 93
#     learning_rate: 0.0037838086755506133
